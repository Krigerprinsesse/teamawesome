# %%
import json
import requests
import csv
import pandas as pd

# %%
women_CEOs_path = "2019_WomenCEO_list.csv"
women_CEOs = pd.read_csv(women_CEOs_path)
women_CEOs
# Out:
#                   CEO                  Company  2019 Fortune 500 ranking  \
# 0         Laura Alber          Williams-Sonoma                       495
# 1      Beth E. Mooney                  KeyBank                       413
# 2     Tricia Griffith  Progressive Corporation                        99
# 3    Ginni Rometty[3]                      IBM                        38
# 4       Safra A. Catz       Oracle Corporation                        81
# 5  Marillyn Hewson[4]          Lockheed Martin                        60
# 6     Phebe Novakovic         General Dynamics                        92
# 7         Mary Dillon              Ulta Beauty                       449
# 8          Mary Barra           General Motors                        13
# 9     Barbara Rentler              Ross Stores                       209
#
#   effective date as CEO Ticker Symbol (NYS/NASDAQ)
# 0                5/1/10                        WSM
# 1                5/1/11                        KEY
# ...

# %%
tickers = women_CEOs["Ticker Symbol (NYS/NASDAQ)"]
api_key = "G3HAJBMGFTXEOWHT"
url = "https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol="
stock_response = []
#https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=MSFT&apikey=demo

for x in range(len(tickers)):
    print(f"Making request number: {x} for : {tickers[x]}")

    # Get one of the posts
    post_response = requests.get("https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=WSMT&apikey=G3HAJBMGFTXEOWHT").json()
    
    # Save post's JSON
    stock_response.append(post_response)
# Out:
# Making request number: 0 for : WSM
# Making request number: 1 for : KEY
# Making request number: 2 for : PGR
# Making request number: 3 for : IBM
# Making request number: 4 for : ORCL
# Making request number: 5 for : LMT
# Making request number: 6 for : GD
# Making request number: 7 for : ULTA
# Making request number: 8 for : GM
# Making request number: 9 for : ROST

# %%
stock_response
# Out:
# [{'Error Message': 'Invalid API call. Please retry or visit the documentation (https://www.alphavantage.co/documentation/) for TIME_SERIES_MONTHLY.'},
#  {'Error Message': 'Invalid API call. Please retry or visit the documentation (https://www.alphavantage.co/documentation/) for TIME_SERIES_MONTHLY.'},
#  {'Error Message': 'Invalid API call. Please retry or visit the documentation (https://www.alphavantage.co/documentation/) for TIME_SERIES_MONTHLY.'},
#  {'Error Message': 'Invalid API call. Please retry or visit the documentation (https://www.alphavantage.co/documentation/) for TIME_SERIES_MONTHLY.'},
#  {'Error Message': 'Invalid API call. Please retry or visit the documentation (https://www.alphavantage.co/documentation/) for TIME_SERIES_MONTHLY.'},
#  {'Error Message': 'Invalid API call. Please retry or visit the documentation (https://www.alphavantage.co/documentation/) for TIME_SERIES_MONTHLY.'},
# ...

# %%
company_response = requests.get(query_url)
company_json = company_response.json()

# %%
print(company_json)
# Out:
# {'Meta Data': {'1. Information': 'Monthly Prices (open, high, low, close) and Volumes', '2. Symbol': 'ORCL', '3. Last Refreshed': '2019-07-31', '4. Time Zone': 'US/Eastern'}, 'Monthly Time Series': {'2019-07-31': {'1. open': '57.1500', '2. high': '60.5000', '3. low': '55.6200', '4. close': '56.3000', '5. volume': '251443357'}, '2019-06-28': {'1. open': '50.5600', '2. high': '57.4700', '3. low': '49.8900', '4. close': '56.9700', '5. volume': '417220273'}, '2019-05-31': {'1. open': '55.3200', '2. high': '55.4150', '3. low': '50.5100', '4. close': '50.6000', '5. volume': '240093024'}, '2019-04-30': {'1. open': '53.8800', '2. high': '55.5300', '3. low': '53.3300', '4. close': '55.3300', '5. volume': '193507042'}, '2019-03-29': {'1. open': '52.5000', '2. high': '54.3750', '3. low': '51.0000', '4. close': '53.7100', '5. volume': '370697217'}, '2019-02-28': {'1. open': '50.5200', '2. high': '53.0300', '3. low': '49.8200', '4. close': '52.1300', '5. volume': '257842921'}, '2019-01-31': {'1. 
# ...
