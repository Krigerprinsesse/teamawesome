# %%
import csv
import pandas as pd

# %%
women_CEOs_path = "2019_WomenCEO_list.csv"
women_CEOs = pd.read_csv(women_CEOs_path)
women_CEOs
# Out:
#                        CEO                                         Company  \
# 0               Mary Barra                                  General Motors
# 1   Gail Koziara Boudreaux                                     Anthem Inc.
# 2         Ginni Rometty[3]                                             IBM
# 3       Marillyn Hewson[4]                                 Lockheed Martin
# 4              Corie Barry                                        Best Buy
# 5            Safra A. Catz                              Oracle Corporation
# 6          Phebe Novakovic                                General Dynamics
# 7          Tricia Griffith                         Progressive Corporation
# 8             Kathy Warden                                Northrop Grumman
# 9             Lynn Good[5]                                     Duke Energy
# 10           Michelle Gass                                          Kohl's
# ...
